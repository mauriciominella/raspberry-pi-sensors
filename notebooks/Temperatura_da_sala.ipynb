# %%
import pandas as pd
df = pd.read_csv ('../data/sensor.csv', header=None, names=['date', 'temp', 'hum'])
print(df.columns)
# Out:
# Index(['date', 'temp', 'hum'], dtype='object')

# %%
df.describe()
# Out:
#               temp          hum
# count  2110.000000  2110.000000
# mean     17.872464    59.892038
# std       1.581155     3.378899
# min      15.600000    39.500000
# 25%      16.600000    57.900000
# 50%      17.300000    60.250000
# 75%      18.900000    62.400000
# max      25.800000    67.200000

# %%
lines = df.plot.line(subplots=True, x='date', y='temp')
lines
# Out:
# array([<AxesSubplot:xlabel='date'>], dtype=object)
